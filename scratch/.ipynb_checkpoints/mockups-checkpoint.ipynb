# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from alpha_vantage.timeseries import TimeSeries


#ts = TimeSeries(key="EEKL6B77HNZE6EB4", output_format='pandas')
#data, meta_data = ts.get_intraday(symbol='SPY',interval='month', outputsize='full')
#data['close'].plot()
#plt.title('Intraday Times Series for the MSFT stock (1 min)')
#plt.show()

# %%
d0 = pd.read_csv("./monthly_SPY.csv")
d0["year"] = d0.apply(lambda row: int(str(row["timestamp"]).split("-")[0]), axis=1)
d0 = d0.loc[d0["year"]>2000]
d0 = d0.reindex(index=d0.index[::-1])

# %%
plt.plot(d0["timestamp"], d0["close"])
plt.show()

# %%
# Out:
#       timestamp      open      high       low     close      volume
# 0    2019-02-19  270.1500  278.5800  267.8300  277.8500   900633415
# 1    2019-01-31  245.9800  270.4700  243.6700  269.9300  2048691645
# 2    2018-12-31  280.2800  280.4000  233.7600  249.9200  3102621849
# 3    2018-11-30  271.6000  281.2200  263.0700  275.6500  2021061342
# 4    2018-10-31  292.1100  293.2100  259.8500  270.6300  3024345990
# 5    2018-09-28  289.8400  293.9400  286.7100  290.7200  1228083461
# 6    2018-08-31  281.5600  291.7400  279.1600  290.3100  1308443632
# 7    2018-07-31  269.5100  284.3700  269.2400  281.3300  1266961027
# 8    2018-06-29  272.4100  279.4800  268.4900  271.2800  1600700314
# 9    2018-05-31  263.8700  274.2500  259.0500  270.9400  1606397329
# 10   2018-04-30  262.5500  271.3000  254.6700  264.5100  2000427231
# 11   2018-03-29  271.4100  280.4100  257.8300  263.1500  2336204952
# 12   2018-02-28  281.0700  283.0600  252.9200  271.6500  2923721958
# ...
